# %% [markdown]
# # Instalação do Spacy
# Execute as células na ordem apresentada

# %%
# !pip install -U pip setuptools wheel

# %%
# !pip install -U spacy

# %%
# !python -m spacy download pt_core_news_sm

# %% [markdown]
# # Código

# %%
import spacy

class NERExtractor:
    def __init__(self):
        # Carregue o modelo spaCy apropriado (por exemplo, "pt_core_news_sm" para o Português)
        self.nlp = spacy.load("pt_core_news_sm")
        self.text = ""

    def set_text(self, text):
        # Define a string global
        self.text = text

    def extract_entities(self):
        if not self.text:
            print("Erro: Nenhum texto foi fornecido.")
            return []

        # Processa o texto com o modelo spaCy
        doc = self.nlp(self.text)

        # Extrai as entidades nomeadas
        entities = [(ent.text, ent.label_) for ent in doc.ents]

        return entities

    def load_text_from_file(self, file_path):
        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                file_content = file.read()
                self.set_text(file_content)
                print("Conteúdo do arquivo carregado com sucesso.")
        except Exception as e:
            print(f"Erro ao carregar o arquivo: {str(e)}")

# Exemplo de uso da classe
if __name__ == "__main__":
    extractor = NERExtractor()
    arquivo = "/content/bulas/bula.txt"
    extractor.load_text_from_file(arquivo)

    if extractor.text:
        print("Texto carregado do arquivo:")
        print(extractor.text)
        entidades = extractor.extract_entities()

        if entidades:
            print("\nEntidades Nomeadas encontradas:")
            for entidade, tipo in entidades:
                print(f"Entidade: {entidade}, Tipo: {tipo}")
        else:
            print("Nenhuma entidade nomeada encontrada.")
# Out:
# Conteúdo do arquivo carregado com sucesso.
# Texto carregado do arquivo:
# BULA DO MEDICAMENTO: Exemplon
#
# Nome do Medicamento: Exemplon
# Princípio Ativo: Fictinol
# Forma Farmacêutica: Comprimidos revestidos
# Apresentação: Caixa com 30 comprimidos
#
# 1. INDICAÇÕES
#    O Exemplon é indicado para o tratamento de condições fictícias, tais como:
#    - Doença imaginária tipo A
#    - Condição hipotética B
#    - Síndrome fictícia C
#
# 2. CONTRAINDICAÇÕES
#    Não utilize o Exemplon se você tiver hipersensibilidade ao princípio ativo Fictinol ou a qualquer componente da fórmula. Consulte seu médico antes de usar este medicamento se estiver grávida, amamentando ou se tiver condições de saúde específicas.
#
# 3. ADVERTÊNCIAS E PRECAUÇÕES
#    - Mantenha fora do alcance das crianças.
#    - Não exceda a dose recomendada pelo seu médico.
#    - Este medicamento pode causar sonolência; evite dirigir veículos ou operar máquinas após o uso.
#    - Informe seu médico sobre outros medicamentos que esteja tomando antes de iniciar o tratamento com Exemplon.
#
# 4. POSOLOGIA
#    A dose recomendada de Exemplon varia de acordo com a condição do paciente e a orientação médica. Siga rigorosamente as instruções do seu médico.
#
# 5. EFEITOS COLATERAIS
#    Como todo medicamento, o Exemplon pode causar efeitos colaterais, tais como:
#    - Sonolência
#    - Tontura
#    - Náusea
#    - Vômitos
#
#    Caso experimente algum efeito colateral persistente ou grave, consulte imediatamente seu médico.
#
# 6. ARMAZENAMENTO
#    Mantenha o Exemplon em sua embalagem original, protegido da luz e umidade, em temperatura ambiente (15-30°C). Não utilize medicamentos com o prazo de validade vencido.
#
# 7. SUPERDOSE
#    Em caso de ingestão acidental de uma quantidade excessiva de Exemplon, procure atendimento médico imediatamente.
#
# 8. VENDA SOB PRESCRIÇÃO MÉDICA
#    O Exemplon só pode ser adquirido mediante prescrição médica.
#
# 9. REGISTRO
#    Registro ANVISA: XXXXXXXX
#
# 10. LABORATÓRIO FICTÍCIO
#     Laboratórios Imaginários Ltda.
#     Endereço Fictício, CEP: 12345-678
#     Telefone: (XX) XXXX-XXXX
#
# Esta bula é meramente fictícia e tem o propósito de exemplificar a estrutura de uma bula de medicamento. Consulte sempre a bula oficial do medicamento prescrito pelo seu médico ou farmacêutico para informações precisas e atualizadas sobre um medicamento específico.
#
#
# Entidades Nomeadas encontradas:
# Entidade: BULA DO MEDICAMENTO, Tipo: MISC
# Entidade: Nome do Medicamento, Tipo: MISC
# Entidade: Princípio Ativo: Fictinol
# Forma Farmacêutica, Tipo: MISC
# Entidade: Apresentação: Caixa, Tipo: MISC
# Entidade: Exemplon, Tipo: ORG
# Entidade: Doença, Tipo: PER
# Entidade: Condição hipotética B, Tipo: MISC
# Entidade: Síndrome, Tipo: PER
# Entidade: C, Tipo: MISC
# Entidade: Exemplon, Tipo: LOC
# Entidade: Fictinol, Tipo: MISC
# Entidade: PRECAUÇÕES, Tipo: PER
# Entidade: Mantenha, Tipo: PER
# Entidade: Informe, Tipo: PER
# Entidade: Exemplon, Tipo: MISC
# Entidade: POSOLOGIA, Tipo: MISC
# Entidade: Exemplon, Tipo: LOC
# Entidade: COLATERAIS, Tipo: MISC
# Entidade: Exemplon, Tipo: ORG
# Entidade: Sonolência, Tipo: LOC
# Entidade: Tontura, Tipo: LOC
# Entidade: Náusea, Tipo: LOC
# Entidade: ARMAZENAMENTO, Tipo: MISC
# Entidade: Mantenha o Exemplon, Tipo: MISC
# Entidade: C, Tipo: MISC
# Entidade: SUPERDOSE, Tipo: ORG
# Entidade: Exemplon, Tipo: MISC
# Entidade: VENDA, Tipo: ORG
# Entidade: MÉDICA, Tipo: MISC
# Entidade: Exemplon, Tipo: ORG
# Entidade: REGISTRO, Tipo: ORG
# Entidade: Registro ANVISA, Tipo: MISC
# Entidade: XXXXXXXX, Tipo: MISC
# Entidade: FICTÍCIO
#     Laboratórios Imaginários Ltda, Tipo: MISC
# Entidade: Endereço Fictício, Tipo: PER
